# %%
# import geopandas as gpd
import numpy as np
import pandas as pd
import copy

# %%
data = pd.read_csv("./data/nndb_flat.csv")

# %%
data.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip CommonName MfgName ScientificName  Energy_kcal  \
# 0              Butter, salted        NaN     NaN            NaN        717.0
# 1  Butter, whipped, with salt        NaN     NaN            NaN        717.0
# 2       Butter oil, anhydrous        NaN     NaN            NaN        876.0
# 3                Cheese, blue        NaN     NaN            NaN        353.0
# 4               Cheese, brick        NaN     NaN            NaN        371.0
#
#    Protein_g  Fat_g  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  \
# 0       0.85  81.11  ...        0.0075      0.002625          0.026154
# 1       0.85  81.11  ...        0.0075      0.002625          0.026154
# 2       0.28  99.48  ...        0.0000      0.000188          0.003846
# 3      21.40  28.74  ...        0.0900      0.063500          0.293846
# 4      23.24  29.68  ...        0.0500      0.007375          0.270000
#
#    Thiamin_USRDA  Calcium_USRDA  Copper_USRDA  Magnesium_USRDA  \
# 0       0.004167       0.020000      0.000000         0.004762
# 1       0.004167       0.020000      0.000018         0.004762
# 2       0.000833       0.003333      0.000001         0.000000
# 3       0.024167       0.440000      0.000044         0.054762
# 4       0.011667       0.561667      0.000027         0.057143
#
#    Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0          0.034286        0.018182    0.008182
# 1          0.032857        0.018182    0.004545
# 2          0.004286        0.000000    0.000909
# 3          0.552857        0.263636    0.241818
# 4          0.644286        0.263636    0.236364
#
# [5 rows x 45 columns]

# %%
data.notnull()
data = data.drop(columns=['CommonName','MfgName','ScientificName'])

# %%
data.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip  Energy_kcal  Protein_g  Fat_g  Carb_g  Sugar_g  \
# 0              Butter, salted        717.0       0.85  81.11    0.06     0.06
# 1  Butter, whipped, with salt        717.0       0.85  81.11    0.06     0.06
# 2       Butter oil, anhydrous        876.0       0.28  99.48    0.00     0.00
# 3                Cheese, blue        353.0      21.40  28.74    2.34     0.50
# 4               Cheese, brick        371.0      23.24  29.68    2.79     0.51
#
#    Fiber_g  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  Thiamin_USRDA  \
# 0      0.0  ...        0.0075      0.002625          0.026154       0.004167
# 1      0.0  ...        0.0075      0.002625          0.026154       0.004167
# 2      0.0  ...        0.0000      0.000188          0.003846       0.000833
# 3      0.0  ...        0.0900      0.063500          0.293846       0.024167
# 4      0.0  ...        0.0500      0.007375          0.270000       0.011667
#
#    Calcium_USRDA  Copper_USRDA  Magnesium_USRDA  Phosphorus_USRDA  \
# 0       0.020000      0.000000         0.004762          0.034286
# 1       0.020000      0.000018         0.004762          0.032857
# 2       0.003333      0.000001         0.000000          0.004286
# 3       0.440000      0.000044         0.054762          0.552857
# 4       0.561667      0.000027         0.057143          0.644286
#
#    Selenium_USRDA  Zinc_USRDA
# 0        0.018182    0.008182
# 1        0.018182    0.004545
# 2        0.000000    0.000909
# 3        0.263636    0.241818
# 4        0.263636    0.236364
#
# [5 rows x 42 columns]

# %%
descrip = np.array(data['Descrip'])
words = ""
for i in descrip:
    words += i.lower()+','
differentwords = (words.split(','))

# %%
count = 0
for i in differentwords:
    if('pizza' in i):
        count+=1

# %%
count
# Out:
# 97

# %%
len(set(differentwords))
# Out:
# 5952

# %%
groups = np.array(data['FoodGroup'])
len(set(groups))
# Out:
# 25

# %%
set(differentwords)
# Out:
# {'',
#  ' mesquite flavor',
#  ' country-style ribs',
#  ' 2 1/2 minute cook time',
#  '  85% lean / 15% fat',
#  ' gripz',
#  ' tagalongs cookies',
#  ' canadian',
#  ' easy open',
#  ' mini chocolate chip cookies',
#  ' chanterelle',
#  ' veal',
#  ' peanut butter sandwich',
#  ' arroz con frijoles negros (rice and black beans)',
#  ' shoulder breast',
#  ' with cheese',
#  ' sugar substitute',
#  ' lemon',
#  'butterbur',
#  ' garden vegetable',
#  ' unflavored',
#  ' original 7-grain crackers',
#  ' pregestimil',
#  ' (bay and sea)',
#  ' applesauce and pineapple',
#  ' parmesan',
#  ' top loin petite roast/filet',
#  ' keebler chocolate graham selects',
#  ' 3.7% milkfat',
#  'morningstar farms grillers quarter pound veggie burger',
#  'meat drippings (lard',
#  ' cream of onion soup',
#  ' arm pot roast',
#  ' sandwich-type with peanut butter filling',
#  ' rice',
#  ' with cheese and egg',
#  ' enfacare lipil',
#  ' (boston butt)',
#  ' baby ruth bar',
#  ' hamburger or hotdog',
#  ' jalapenos nacho sliced peppers',
#  ' sweet potatoes strained',
#  ' sugar free',
#  ' less/reduced sodium',
#  ' queso seco',
#  ' for baking',
#  'cornstarch',
#  'chilchen (red berry beverage) (navajo)',
#  ' slow roasted beef with mushrooms soup',
#  ' chicken sticks',
#  ' canola harvest soft spread (canola',
#  ' egg and cheese',
#  ' seatrout',
#  ' 95% lean meat / 5% fat',
#  ' italian flatbread',
#  'doughnuts',
#  ' fat-free',
#  ' brown sugar cinnamon roll',
#  ' pasteurized process',
#  " mother's peanut butter bumpers cereal",
#  'granola bar',
#  ' 15% fat',
#  ' soybean (hydrogenated) and cottonseed (hydrogenated)',
#  ' la ricura',
#  ' savory pot roast soup',
#  'yellow rice with seasoning',
#  ' coconut creme',
#  ' organic flax plus flakes',
#  ' skin and breading',
#  'cranberries',
#  ' 12 grams protein per 8 ounce',
#  ' export sodas crackers',
#  'acorn stew (apache)',
#  ' next step prosobee',
#  " croissan'wich with egg and cheese",
#  ' snail',
#  ' honey mustard dressing',
#  'sweet potato',
#  ' prosobee',
#  'morningstar farms hot and spicy veggie sausage patties',
#  " kellogg's low fat granola without raisins",
#  ' whole kernel',
#  'sour dressing',
#  ' natural granola apple cranberry almond',
#  ' instant',
#  ' beef broth bouillon and consomme',
#  'liverwurst spread',
#  ' high fiber',
#  ' from roasted and toasted kernels (most common type)',
#  ' sockeye (red)',
#  ' turkey ham (10% water added)',
#  ' (west indian cherry)',
#  ' nachos supreme',
#  ' banana with mixed berries',
#  'gardenburger black bean chipotle burger',
#  ' phineas and ferb soup',
#  ' prepackaged or deli-sliced',
#  ' deli style',
#  ' peppercorn dressing',
#  ' stuffing',
#  ' neck chops',
#  ' gumdrops',
#  ' boxed',
#  ' (matai)',
#  ' braunschweiger liver sausage (sliced)',
#  'shortening',
#  ' good start supreme',
#  ' grated',
#  ' lowfat',
#  ' high oleic',
#  ' corn cakes',
#  ' chicken and beef',
#  " kellogg's rice krispies treats squares",
#  ' instant oatmeal organic',
#  ' cooked (southwest)',
#  ' hershey',
#  ' oatmeal dark chocolate cookies',
#  ' kashi golden goodness',
#  ' regular pack',
#  ' opossum',
#  ' prunes',
#  ' low iron',
#  'tomato powder',
#  'wheat',
#  'morningstar farms grillers vegan',
#  ' savory vegetable soup',
#  'rolls',
#  ' unbaked',
#  " croissan'wich with sausage and cheese",
#  ' hearty chicken with vegetables soup',
#  ' lettuce',
#  ' full rump',
#  ' wieners (cheese hot dogs with turkey)',
#  'louis rich',
#  ' calcium fortified (fat free or skim)',
#  ' (dried gourd strips)',
#  " m&m's minis milk chocolate candies",
#  ' apricot',
#  ' beef consomme',
#  ' with high vitamin c with other added vitamins',
#  ' betty crocker supermoist yellow cake mix',
#  ' osso buco',
#  ' sesame seed kernels',
#  ' mega noodle in chicken broth',
#  " kellogg's frosted mini-wheats",
#  ' sprouted',
#  ' pan-browned',
#  'blueberries',
#  ' total edible',
#  ' candied',
#  ' flaxseed',
#  ' reesesticks crispy wafers',
#  'tortilla',
#  ' oatmeal cookies',
#  ' pepsi',
#  ' all natural light vanilla',
#  ' meat-filled',
#  ' thick & fluffy',
#  ' double fudge creme sandwich cookies',
#  " reese's puffs",
#  ' hot fudge',
#  "carrabba's italian grill",
#  ' sweet chocolate coated fondant',
#  ' apple',
#  ' vanilla sugar wafer',
#  ' nature valley',
#  ' arm picnic',
#  ' calcium-fortified',
#  ' enchirito',
#  ' yogurt-covered',
#  ' open pit',
#  ' cheese tamales',
#  ' soy (partially hydrogenated )',
#  ' flat half',
#  ' pompano',
#  ' fully hydrogenated',
#  ' coffee',
#  'kellogg mini-wheats frosted bite size touch of fruit raisin',
#  ' all (gin',
#  'seeds',
#  ' butterscotch',
#  ' neufchatel',
#  'guavas',
#  'silk key lime soy yogurt',
#  ' potato salad',
#  ' dumpling with mutton (navajo)',
#  ' from unroasted kernels (non-chemically removed seed coat)',
#  ' japanese style',
#  ' french fried in vegetable oil',
#  ' taco with chicken',
#  ' creamy stroganoff sauce with pasta',
#  ' chowchow',
#  ' loin saddle',
#  'boysenberries',
#  ' suet',
#  ' cream of potato',
#  ' ham and cheese sandwich',
#  ' dates and walnuts',
#  ' italian style',
#  ' anchovy',
#  'cress',
#  ' eyes (alaska native)',
#  ' strip steaks',
#  ' beef jerky',
#  ' dutch apple',
#  ' beef with vegetables',
#  ' loaded cherry',
#  ' uncoated',
#  ' cola or pepper-types',
#  'wheat germ',
#  'pokeberry shoots',
#  'cranberry',
#  ' whole milk and margarine added',
#  ' center loin (chops)',
#  ' with apples',
#  ' sardine',
#  ' with wheat flour added',
#  ' soba',
#  ' raw (shoshone bannock)',
#  ' oyster stew',
#  ' beef and tomato sauce',
#  ' not prepared',
#  'peppermint',
#  ' with broth',
#  ' goobers chocolate covered peanuts',
#  ' palm kernel (hydrogenated) ',
#  ' berry flavored',
#  'pumpkin',
#  ' back meat and skin',
#  ' chicken broccoli cheese & potato soup',
#  ' boost plus',
#  ' banana (navajo)',
#  " m&m's crispy chocolate candies",
#  ' long-grain',
#  ' island vanilla',
#  ' chocolate chip & pecan cookies',
#  " chicken noodleo's soup",
#  ' half the caffeine',
#  ' with cheese and beef',
#  ' prepared from granules with milk',
#  ' no alcohol',
#  ' betty crocker fruit roll ups',
#  ' cupu assu',
#  ' external fat only',
#  'ready-to-drink reduced fat milk beverage',
#  ' with crunch coating',
#  'teff',
#  ' holiday jingles cookies',
#  ' egg & cheese biscuit',
#  ' frosted toast crunch',
#  ' ricotta',
#  ' cheesy potato with bacon flavor soup',
#  ' orange flavor',
#  ' vegetable lo mein',
#  ' rolo caramels in milk chocolate',
#  ' toast & peanut butter sandwich crackers',
#  ' vegetable oil spread',
#  ' kraft',
#  'lard',
#  'potato pancakes',
#  ' sweetened',
#  ' country fried shrimp platter',
#  ' french crullers',
#  ' peanut flavor',
#  ' raw (northern plains indians)',
#  ' boiled (navajo)',
#  ' onion and garlic italian sauce',
#  ' capons',
#  ' all purpose salad or cooking',
#  'coffee and cocoa (mocha) powder',
#  'spanish rice mix',
#  "morningstar farms italian herb chik'n pattie",
#  'barley flour or meal',
#  ' bologna (fat free)',
#  ' frosted (includes honey buns)',
#  ' subcutaneous fat',
#  ' wieners (beef franks',
#  'potatoes',
#  ' smokie links sausage',
#  'potato puffs',
#  ' napa',
#  ' beans',
#  ' beef mushroom',
#  ' raisin nut',
#  " reese's peanut butter cups",
#  ' single brand',
#  ' with added vitamin c',
#  " pop'ables milky way brand bite size candies",
#  'eggnog',
#  ' snickers cruncher',
#  ' onion crackers',
#  ' marshmallows',
#  ' thank u berry munch cookies',
#  ' pop-tarts mini crisps',
#  ' retail cuts',
#  ' cheese stuffed crust',
#  ' boneless',
#  'morningstar farms breakfast sausage links',
#  ' green taco sauce',
#  ' pork loin filets',
#  " newman's own low fat balsamic vinaigrette",
#  ' cake-type (includes trolley cakes)',
#  ' walnuts',
#  ' whole (shank and sirloin)',
#  ' hard-boiled',
#  ' breast meat only',
#  ' sofrito',
#  'mixed vegetable and fruit juice drink',
#  ' usda commodity corn and rice (includes all commodity brands)',
#  ' old el paso',
#  ' 8 inch',
#  'ice cream cookie sandwich',
#  ' edam',
#  ' sirloin burger with vegetables',
#  ' light meat without skin',
#  'worthington chic-ketts',
#  ' paste',
#  ' crude',
#  ' wheatables',
#  ' broccoli cheese soup',
#  ' (poke)',
#  'canada goose',
#  ' benecol light spread',
#  "morningstar farms veggie sweet and sour chik'n",
#  ' roast beef on white bread with lettuce and tomato',
#  ' chuck',
#  ' vegetables and lamb',
#  ' happy trail mix cookies',
#  ' brewed from bags',
#  ' (vegetable oyster)',
#  ' typical basis for ice cream coatings',
#  ' with ham',
#  ' milkshake mix',
#  ' applesauce and apricots',
#  'pears',
#  ' cinnamon toasters',
#  ' waffles',
#  'usda commodity',
#  ' all areas',
#  ' brazilnuts',
#  ' 93% lean meat / 7% fat',
#  ' salad or cooking',
#  ' sakwavikaviki (hopi)',
#  '   trimmed to 1/8" fat',
#  'oat bran',
#  ' garlic chicken with pasta (chicken not included)',
#  ' 85% lean',
#  ' cutlet',
#  'beverage',
#  ' chilled',
#  ' protein (includes gluten)',
#  ' queso blanco',
#  ' spaghettios with meatballs',
#  ' standard snack-type',
#  ' bleached',
#  ' black bean',
#  ' gamesa sabrosas',
#  ' banana bread',
#  'pectin',
#  ' packed in oil (alaska native)',
#  ' drinking',
#  'deer (venison)',
#  ' orange and banana',
#  'worthington low fat veja-links',
#  ' raw (alaska native)',
#  ' honey nut clusters',
#  ' sitka',
#  "mother's loaf",
#  ' bistro multigrain crackers',
#  " kellogg's corn pops",
#  ' with beef and chili peppers',
#  'kfc',
#  'morningstar farms breakfast bacon strips',
#  ' jalapeno',
#  ' organic picante sauce',
#  ' rice-based',
#  ' porterhouse steak',
#  ' free range',
#  ' 9 oz house sirloin steak',
#  'kielbasa',
#  ' fermented (alaska native)',
#  ' california',
#  ' mars snackfood us',
#  ' bean with bacon',
#  ' heated (microwave)',
#  ' pizza',
#  ' honey bunches of oats',
#  ' cereal grain beverage',
#  ' tilsit',
#  ' vitamin d fortified',
#  ' sea bass',
#  ' snickers marathon multigrain crunch bar',
#  ' cocoavia',
#  'bagel',
#  'capers',
#  ' non-dairy',
#  ' great grains crunchy pecan cereal',
#  ' cinnamon',
#  ' sweetened with sugar',
#  ' liqueur',
#  'little caesars 14" original round meat and vegetable pizza',
#  ' vitamins b6 and b12',
#  ' includes skin',
#  ' mixed (corn',
#  ' and cheese',
#  ' nachos',
#  ' ribs prepared',
#  ' chocolatey chip thins cookies',
#  ' chocolate malt powder',
#  " hershey's",
#  ' mixed berry',
#  " nature's path",
#  " kellogg's cinnamon jacks",
#  'oat flour',
#  ' mayonnaise type',
#  ' produced by alcohol extraction',
#  ' milky way caramels. dark chocolate covered',
#  ' cool nestea ice tea lemon flavor',
#  ' plate',
#  ' top sirloin petite roast',
#  ' all-bran',
#  ' turmeric',
#  ' without skin',
#  ' honey)',
#  ' municipal',
#  ' bbq',
#  'dairy',
#  'new england brand sausage',
#  'loma linda low fat big franks',
#  ' woks and light frying',
#  ' leaf fat',
#  ' cola or pepper-type',
#  ' chocolate creme sandwich cookies',
#  ' gluten free',
#  ' garlic powder',
#  ' brine pack',
#  " kellogg's cinnabon cereal",
#  ' quaker oatmeal to go',
#  ' meat or poultry',
#  ' crispy bar with peanut butter filling',
#  ' lemberger',
#  ' dannon oikos',
#  ' harvest cheddar flavor',
#  ' mayonnaise and mayonnaise-type',
#  'cracker meal',
#  'mori-nu',
#  ' apricot with tapioca',
#  'fungi',
#  ' soft taco with ground beef',
#  ' snack cakes',
#  ' cookie',
#  ' malt-o-meal',
#  ' with butter sauce',
#  ' prepared from flakes without milk',
#  ' california and arizona',
#  ' batter',
#  ' pretzel crackers',
#  'brotwurst',
#  ' pinot gris (grigio)',
#  ' gold',
#  ' flakes without milk',
#  ' picante sauce',
#  ' 72% lean / 28% fat',
#  ' linoleic (less than 60%)',
#  ' (partially hydrogenated)',
#  ' special dietary (includes lemon-flavored)',
#  ' flavored with meat italian sauce',
#  'lupins',
#  ' toasted (includes sourdough)',
#  ' goose',
#  'turnip greens and turnips',
#  ' nabisco grahams crackers',
#  ' made from powdered mix',
#  ' blade (chops or roasts)',
#  ' apple cinnamon',
#  ' corned beef hash',
#  ' light meat (breast or wing)',
#  ' black bean soup',
#  ' swanson chicken broth 99% fat free',
#  'pillsbury grands',
#  'sweet rolls',
#  ' health valley',
#  'squab',
#  ' bacon',
#  ' aquafina',
#  'hormel',
#  ' wild (northern plains indians)',
#  ' unheated',
#  ' chicken tenders platter',
#  ' soy chips or crisps',
#  'tortilla chips',
#  ' fruit punch',
#  ' fudge dipped',
#  'seasoning mix',
#  ' heart smart- roasted red pepper and garlic italian sauce',
#  'usda commodity pears',
#  'soy sauce made from soy and wheat (shoyu)',
#  'corn grain',
#  ' with corn flour coating (corndog)',
#  ' cinnamon-raisin',
#  ' prepackaged or deli',
#  ' low-fat',
#  ' beef noodle',
#  ' soy (partially hydrogenated)  and cottonseed',
#  ' liverwurst',
#  ' applesauce',
#  'tomato sauce',
#  ' nuggets',
#  'lambs quarters',
#  ' whole wheat (includes multi-grain)',
#  ' chocolate sandwich creme cookies',
#  'silk vanilla',
#  ' without added ascorbic acid',
#  ' lactofree lipil',
#  ' hotdog',
#  ' shortcake',
#  'tangerine juice',
#  ' original crust',
#  ' rising crust',
#  'luncheon sausage',
#  ' top loin petite roast',
#  ' healthy request microwavable bowls',
#  ' chocolate marshmallow',
#  ' center rib (chops)',
#  ' (chinese preserving melon)',
#  'cattail',
#  "wend'ys",
#  ' medley crunch',
#  ' puree',
#  ' cos or romaine',
#  'gelatins',
#  ' lil crunchies',
#  ' cheese and salsa- medium',
#  ' spaghetti and meatballs',
#  'waxgourd',
#  ' ultimate deep dish crust',
#  ' uncle sam cereal',
#  ' chicken breast (honey glazed)',
#  ' pasta with cheese filling',
#  ' croissant',
#  'vitasoy usa organic nasoya',
#  'pork sausage rice links',
#  'digiorno pizza',
#  ' chocolate lucky charms',
#  ' heart (alaska native)',
#  ' prepared-from-recipe',
#  " kellogg's krave smores",
#  ' square-cut shoulder chops',
#  ' slimfast shake mix',
#  ' tequila sunrise',
#  ' biscuit scramblers',
#  ' iced cookies',
#  ' fruit filling',
#  ' sesame',
#  ' palm kernel (hydrogenated)',
#  ' eye of round steak',
#  'worthington dinner roast',
#  ' rolled',
#  'cereals',
#  ' ranch dressing',
#  ' honey almond flax',
#  ' prepared with equal volume water',
#  ' contains wheat flour and rice flour',
#  ' 70-85% cacao solids',
#  'pepeao',
#  ' liquid from stewed kidney beans',
#  ' with cinnamon and spice',
#  'garlic',
#  ' hominy with mutton (navajo)',
#  ' use for baking',
#  ' late harvest',
#  ' sodium-citrate and salt',
#  ' peach cobbler',
#  'breakfast bar',
#  ' sundae',
#  "campbell's soup on the go",
#  ' peanut butter cookies',
#  ' fruit',
#  ' no cholesterol',
#  'lasagna',
#  ' pancake',
#  ' original big biscuit',
#  ' in skin',
#  'goat',
#  ' creamy chicken and dumplings soup',
#  ' chopped beef',
#  ' cheese smokie',
#  ' special k protein shake',
#  'polish sausage',
#  ' farmed',
#  ' with swiss cheese',
#  'butter oil',
#  ' peanut butter toast crunch',
#  ' chuck eye roast',
#  'pheasant',
#  ' cheshire',
#  ' lean only',
#  ' eel',
#  'buckwheat',
#  ' original 3-bean chips',
#  ' with meatballs in tomato sauce',
#  ' chocolate-coated',
#  ' au jus',
#  'gardenburger original',
#  " newman's own creamy caesar dressing",
#  ' 96% lean / 4% fat',
#  ' industrial and retail',
#  ' quaker multigrain oatmeal',
#  ' (sockeye)',
#  ' hulled',
#  ' wafflers',
#  'pepper',
#  'soy protein isolate',
#  ' with lettuce and mayonnaise',
#  ' bagel chips',
#  ' full cut',
#  ' linoleic (less than 1%)',
#  ' prepared with sugar',
#  ' kashi tlc bar',
#  ' coconut',
#  ' symphony milk chocolate bar',
#  ' or crimini',
#  ' canola with antifoaming agent',
#  ' grape juice',
#  ' pre-basted',
#  ' original graham cookies',
#  ' whiskey) 80 proof',
#  ' with whitener',
#  ' with onions',
#  'bratwurst',
#  ' chocolate pie crust',
#  'kashi pizza',
#  'chicken pot pie',
#  ' without skin and bones',
#  ' candy bar',
#  ' canola (partially hydrogenated) oil for deep fat frying',
#  'cheesefurter',
#  ' usda choice',
#  'snacks',
#  ' poppy',
#  'peanuts',
#  ' diet fruit medley',
#  ' 93% lean',
#  ' turkey salami cotto',
#  ' original recipe',
#  ' crispy chicken sandwich',
#  ' twix peanut butter cookie bars',
#  ' solids with bone and liquid',
#  ' regular patty; with condiments',
#  ' head cheese',
#  ' special k',
#  ' short loin',
#  'winged bean tuber',
#  ' grilled chicken',
#  'morningstar farms spicy black bean burger',
#  ' rye',
#  'peppered loaf',
#  ' ribeye petite roast',
#  ' milky way midnight bar',
#  'pinon nuts',
#  ' dry',
#  ' caraway seed',
#  ' swiss',
#  ' bun length)',
#  ' strawberry fields',
#  ' healthy request italian wedding soup',
#  'coffee substitute',
#  ' pumpernickel',
#  ' meat-caribou (alaskan ice cream) (alaska native)',
#  " mother's cinnamon oat crunch",
#  ' herbal extract powder from stevia leaf',
#  ' from retail parts',
#  ' nutritional drink',
#  ' vegetables',
#  ' salad',
#  ' 34 proof',
#  ' large end (ribs 6-9)',
#  ' baked in skin',
#  ' salada brewed from bags',
#  'piki bread',
#  'papa john\'s 14" cheese pizza',
#  ' as purchased',
#  ' burrito',
#  'arrowhead',
#  ' bottom round steak/roast',
#  ' tomato soup',
#  ' do-si-dos cookies',
#  ' mutton',
#  ' berliner',
#  " reese's pieces candy",
#  ' farley candy',
#  ' steller',
#  'macaroni',
#  ' granola bar',
#  ' low moisture',
#  ' soybean',
#  ' filet-o-fish (without tartar sauce)',
#  ' smart balance light buttery spread',
#  'vegetarian meatloaf or patties',
#  ' french onion flavor',
#  ' batter-dipped and fried',
#  ' soft taco',
#  ' club & cheddar sandwich crackers',
#  ' italian lasagna',
#  ' mint creme middles',
#  'wild rice',
#  ' breaded',
#  ' white fudge dipped pretzels',
#  'elderberries',
#  ' weetabix whole grain cereal',
#  ' green goddess',
#  ' vanilla wafer',
#  ' extra lean and regular',
#  ' rainbow',
#  ' cracked-wheat',
#  ' shoulder steak',
#  ' without added vitamin a and vitamin d',
#  ' cookie jar classics',
#  ' asian',
#  ' smoked sliced beef',
#  ' backribs',
#  ' yeast-leavened',
#  ' caramel',
#  'leavening agents',
#  ' spinach',
#  ' cracker chips',
#  'ruffed grouse',
#  'luncheon slices',
#  ' herring eggs on giant kelp',
#  'silk plus for bone health',
#  ' french lentil',
#  ' leaves',
#  ' cinnamon grahams',
#  'mustard',
#  ' pasta',
#  ' double',
#  ' shank',
#  'turkey breast',
#  ' with added sugar',
#  'mammy-apple',
#  ' mr. goodbar chocolate bar',
#  ' chinese (pak-choi)',
#  ' flavors not chocolate',
#  ' separable fat',
#  'worthington veja-links',
#  'swanson broth',
#  ' arm',
#  ' baked cooked 96% fat free)',
#  'swanson',
#  ' starburst fruit chews',
#  ' sun country',
#  ' steak cut',
#  ' meat only',
#  ' cream of vegetable',
#  ' frosted cherry',
#  ' chicken',
#  ' fully cooked',
#  " from kids' menu",
#  ' canned in water',
#  ' burrito supreme with chicken',
#  ' made from soy',
#  ' with frosting or icing',
#  ' beef broth',
#  ' soy (partially hydrogenated ) and soy (winterized)',
#  ' honey roasted',
#  ' yogurt covered with vitamin c',
#  ' mini meatball italian sauce',
#  ' marshmallow',
#  ' cheese and lettuce',
#  ' snickers almond bar',
#  ' frosted (include apples',
#  ' meat and skin with breading',
#  ' green tea',
#  ' jumbo fudge sticks',
#  'little caesars 14" cheese pizza',
#  ' loaved',
#  'spaghetti',
#  'healthy request tomato juice',
#  ' hamburger; double',
#  "mcdonald's",
#  ' tip side',
#  ' enriched (n x 5.70)',
#  ' frozen',
#  ' baked potato with cheddar & bacon bits soup',
#  ' full throttle',
#  ' cheese on wheat sandwich crackers',
#  'cheesecake commercially prepared',
#  ' peanut butter',
#  'beet greens',
#  ' large patty; plain',
#  ' caramel delight',
#  ' with egg and bacon',
#  'kraft velveeta pasteurized process cheese spread',
#  ' hazelnut',
#  ' sweetened with non-nutritive sweetener',
#  " s'mores",
#  ' inside',
#  ' low bush or lingenberry',
#  'fruit butters',
#  'popeyes',
#  ' hot fudge sundae',
#  ' flower clusters',
#  ' lamb',
#  'tomatoes',
#  ' carrots and beef',
#  ' sesame butter',
#  ' tops only',
#  ' original crackers',
#  ' all natural light french chocolate',
#  ' healthy request vegetable soup',
#  ' confectionery',
#  ' salted and fermented (fuyu)',
#  ' teriyaki',
#  ' regular patty and bun',
#  ' pilaf',
#  ' bean with bacon soup',
#  ' deluxe grahams cookies',
#  ' special dark chocolate bar',
#  'orange drink',
#  ' melba toast',
#  ' drumstick',
#  ' pickle pimiento loaf (with chicken)',
#  ' brown rice',
#  ' sweet and sour pork',
#  ' cheeseburger; single',
#  ' mountain dew original',
#  ' with tartar sauce and cheese',
#  'pasta mix',
#  ' mouvedre',
#  'parmesan cheese topping',
#  ' french toaster sticks',
#  'corn bran',
#  ' allspice',
#  'formulated bar',
#  ' bacon and tomato club sandwich',
#  ' american or cheddar cheese base',
#  ' large or small curd',
#  ' with icing or coating',
#  ' home-prepared with margarine',
#  ' oat cluster cheerios crunch',
#  ' whopper',
#  ' macaroni and tomato and beef',
#  ' advance with iron',
#  ' chili powder',
#  ' popsicle scribblers',
#  ' fruity dyno-bites',
#  ' high oleic (70%)',
#  ' liver (alaska native)',
#  ' wheat and bran',
#  'vermicelli',
#  ' and grape popsicle pops',
#  'fruit flavored drink',
#  'beef broth and tomato juice',
#  ' cinnamon nut)',
#  ' skin with salt',
#  ' big mac',
#  " kellogg's low fat granola bar",
#  ' maple brown sugar life cereal',
#  ' rump centre',
#  ' taco with beef',
#  'loma linda swiss stake with gravy',
#  'strawberries',
#  "campbell's mushroom gravy",
#  ' soda',
#  ' casaba',
#  ' aa lipil',
#  ' vietnamese carrot lemongrass',
#  ' graduates',
#  ' garden',
#  ' multigrain cereal and added iron',
#  ' bottom round roast',
#  ' premium grilled chicken ranch blt sandwich',
#  'oven-roasted chicken breast roll',
#  ' low linolenic',
#  'chili',
#  'passion-fruit',
#  ' pork)',
#  ' light whipping',
#  ' syrah',
#  ' scup',
#  ' pears and pineapple',
#  " kellogg's rice krispies",
#  ' cervelat',
#  ' potatoes',
#  ' paprika',
#  ' mushroom with beef stock',
#  'loganberries',
#  ' raspberry',
#  ' jellybeans',
#  ' carcass',
#  'sapodilla',
#  ' restructured',
#  "wendy's",
#  'winged bean leaves',
#  ' confectioners coating',
#  ' fontina',
#  ' pina colada',
#  ' avocado',
#  ' added vitamin c',
#  ' mechanically deboned',
#  ' mutton tallow)',
#  ' seedlings (alaska native)',
#  ' with vanilla frosting',
#  ' cinnamon toast grahams',
#  ' familia',
#  ' halavah',
#  " friday's shrimp",
#  'garlic bread',
#  ' uses similar to 95 degree hard butter',
#  ' cinnamon almond',
#  ' soybean oil',
#  ' home prepared',
#  ' high-fat',
#  ' tripe',
#  ' ice cream shoppe frosted vanilla milkshake toaster pastries',
#  ' bar or stick',
#  ' sausage biscuit with egg',
#  ' honey almond',
#  "campbell's homestyle potato broccoli cheese soup",
#  ' seam fat only',
#  ' unenriched',
#  ' or baked',
#  ' pita crisps',
#  ' granulated',
#  ' snack sticks',
#  ' chicken vegetable with potato and cheese',
#  'fruit salad',
#  ' big crackers',
#  ' precooked',
#  ' vegetables tossed',
#  ' golden delicious',
#  ' chinook',
#  ' vegetable chips',
#  ' degermed',
#  ' sandwich-type with cheese filling',
#  ' with real strawberries',
#  ' original waffle',
#  ' cheese enchilada',
#  " kellogg's krave double chocolate cereal",
#  ' fudge',
#  ' ready-to-bake',
#  ' dietetic (with sodium saccharin)',
#  ' mixed grain',
#  'kiwifruit',
#  'coffeecake',
#  ' oat blenders with honey & almonds',
#  'lambsquarters',
#  ' banana',
#  ' quick oats',
#  'fennel',
#  ' american or cheddar',
#  '  3-2-1 plan',
#  ' diarrhea',
#  'guava sauce',
#  ' dark chocolate almond shortbread cookies',
#  ' 2% milkfat',
#  'clam and tomato juice',
#  ' and spareribs',
#  ' red taco sauce',
#  ' instant beef',
#  ' peach almond',
#  'worthington multigrain cutlets',
#  ' bologna (beef light)',
#  ' soup & oyster crackers (large)',
#  ' berry boost',
#  ' immature seeds',
#  ' nutty clusters & almonds',
#  ' arizona iced tea',
#  "campbell's beef gravy",
#  ' whole wheat hot natural cereal',
#  ' jacks vanilla wafers',
#  'shortening household soybean (hydrogenated) and palm',
#  ' raisin-cinnamon (includes apple-cinnamon)',
#  'luxury loaf',
#  ' flesh',
#  ' sausage biscuit',
#  'wocas',
#  ' chocolate chip cookie',
#  ' chenin blanc',
#  ' mayonnaise-like',
#  'bread crumbs',
#  ' tomato chili sauce',
#  ' fruit and juice bars',
#  ' dices',
#  ' grahams',
#  'silk nog',
#  ' prepared-by-recipe',
#  'taro leaves',
#  ' without added salt',
#  ' hind shin',
#  'worthington meatless chicken roll',
#  ' orange pineapple',
#  'frankfurter',
#  ' composite of separable fat',
#  ' lime',
#  ' tea biscuits)',
#  ' prepared from powder',
#  ' 1" steak',
#  " martha white's buttermilk biscuit mix",
#  ' big breakfast',
#  ...}

# %%
set(groups)
# Out:
# {'American Indian/Alaska Native Foods',
#  'Baby Foods',
#  'Baked Products',
#  'Beef Products',
#  'Beverages',
#  'Breakfast Cereals',
#  'Cereal Grains and Pasta',
#  'Dairy and Egg Products',
#  'Fast Foods',
#  'Fats and Oils',
#  'Finfish and Shellfish Products',
#  'Fruits and Fruit Juices',
#  'Lamb, Veal, and Game Products',
#  'Legumes and Legume Products',
#  'Meals, Entrees, and Side Dishes',
#  'Nut and Seed Products',
#  'Pork Products',
#  'Poultry Products',
#  'Restaurant Foods',
#  'Sausages and Luncheon Meats',
#  'Snacks',
#  'Soups, Sauces, and Gravies',
#  'Spices and Herbs',
#  'Sweets',
#  'Vegetables and Vegetable Products'}

# %%
nonveg = [
 'American Indian/Alaska Native Foods',
 'Beef Products',
 'Dairy and Egg Products',
 'Finfish and Shellfish Products',
 'Lamb, Veal, and Game Products',
 'Pork Products',
 'Poultry Products',
 'Sausages and Luncheon Meats',]
remove = ['Restaurant Foods','Meals, Entrees, and Side Dishes', 'Fast Foods', 'Baked Products',]

# %%
len(remove)
# Out:
# 4

# %%
newlabels = []
index = []
j = 0
for i in groups:
    if(i in nonveg):
        newlabels.append('Non-Veg')
    elif(i in remove):
        newlabels.append('Remove')
        index.append(j)
    else:
        newlabels.append('Veg')
    j+=1

# %%
newlabels
# Out:
# ['Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  'Non-Veg',
#  ...]

# %%
len(index)
# Out:
# 1389

# %%
from collections import Counter

# %%
Counter(newlabels)
# Out:
# Counter({'Non-Veg': 3057, 'Veg': 4172, 'Remove': 1389})

# %%
data['FoodGroup'] = newlabels

# %%
data.head()
# Out:
#      ID FoodGroup              ShortDescrip                     Descrip  \
# 0  1001   Non-Veg          BUTTER,WITH SALT              Butter, salted
# 1  1002   Non-Veg  BUTTER,WHIPPED,WITH SALT  Butter, whipped, with salt
# 2  1003   Non-Veg      BUTTER OIL,ANHYDROUS       Butter oil, anhydrous
# 3  1004   Non-Veg               CHEESE,BLUE                Cheese, blue
# 4  1005   Non-Veg              CHEESE,BRICK               Cheese, brick
#
#    Energy_kcal  Protein_g  Fat_g  Carb_g  Sugar_g  Fiber_g  ...  Folate_USRDA  \
# 0        717.0       0.85  81.11    0.06     0.06      0.0  ...        0.0075
# 1        717.0       0.85  81.11    0.06     0.06      0.0  ...        0.0075
# 2        876.0       0.28  99.48    0.00     0.00      0.0  ...        0.0000
# 3        353.0      21.40  28.74    2.34     0.50      0.0  ...        0.0900
# 4        371.0      23.24  29.68    2.79     0.51      0.0  ...        0.0500
#
#    Niacin_USRDA  Riboflavin_USRDA  Thiamin_USRDA  Calcium_USRDA  Copper_USRDA  \
# 0      0.002625          0.026154       0.004167       0.020000      0.000000
# 1      0.002625          0.026154       0.004167       0.020000      0.000018
# 2      0.000188          0.003846       0.000833       0.003333      0.000001
# 3      0.063500          0.293846       0.024167       0.440000      0.000044
# 4      0.007375          0.270000       0.011667       0.561667      0.000027
#
#    Magnesium_USRDA  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0         0.004762          0.034286        0.018182    0.008182
# 1         0.004762          0.032857        0.018182    0.004545
# 2         0.000000          0.004286        0.000000    0.000909
# 3         0.054762          0.552857        0.263636    0.241818
# 4         0.057143          0.644286        0.263636    0.236364
#
# [5 rows x 42 columns]

# %%
datacopy = copy.deepcopy(data)

# %%
data = data.loc[data['FoodGroup'] != 'Remove']

# %%
len(data)
# Out:
# 7229

# %%
data = data.drop(columns=['ShortDescrip','Descrip','ID'])

# %%
energy = data['Energy_kcal']
label = data['FoodGroup']

# %%
data = data.drop(columns=['Energy_kcal','FoodGroup'])

# %%
data.head()
# Out:
#    Protein_g  Fat_g  Carb_g  Sugar_g  Fiber_g  VitA_mcg  VitB6_mg  VitB12_mcg  \
# 0       0.85  81.11    0.06     0.06      0.0     684.0     0.003        0.17
# 1       0.85  81.11    0.06     0.06      0.0     684.0     0.003        0.13
# 2       0.28  99.48    0.00     0.00      0.0     840.0     0.001        0.01
# 3      21.40  28.74    2.34     0.50      0.0     198.0     0.166        1.22
# 4      23.24  29.68    2.79     0.51      0.0     292.0     0.065        1.26
#
#    VitC_mg  VitE_mg  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  \
# 0      0.0     2.32  ...        0.0075      0.002625          0.026154
# 1      0.0     2.32  ...        0.0075      0.002625          0.026154
# 2      0.0     2.80  ...        0.0000      0.000188          0.003846
# 3      0.0     0.25  ...        0.0900      0.063500          0.293846
# 4      0.0     0.26  ...        0.0500      0.007375          0.270000
#
#    Thiamin_USRDA  Calcium_USRDA  Copper_USRDA  Magnesium_USRDA  \
# 0       0.004167       0.020000      0.000000         0.004762
# 1       0.004167       0.020000      0.000018         0.004762
# 2       0.000833       0.003333      0.000001         0.000000
# 3       0.024167       0.440000      0.000044         0.054762
# 4       0.011667       0.561667      0.000027         0.057143
#
#    Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0          0.034286        0.018182    0.008182
# 1          0.032857        0.018182    0.004545
# 2          0.004286        0.000000    0.000909
# 3          0.552857        0.263636    0.241818
# 4          0.644286        0.263636    0.236364
#
# [5 rows x 37 columns]
